# %% [markdown]
# # CONTRASTES DE HIPÓTESIS
#
# Máster: Data Science y Business Analytics
#
# Módulo: Estadística para Científicos de Datos
#
# Profesora: Paloma Fontanillo Rodrigo

# %%
pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ---------------------------------------- 0.0/60.4 kB ? eta -:--:--
#      -------------------------------- ----- 51.2/60.4 kB 871.5 kB/s eta 0:00:01
#      -------------------------------------- 60.4/60.4 kB 796.9 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/10.6 MB ? eta -:--:--
#     --------------------------------------- 0.2/10.6 MB 3.3 MB/s eta 0:00:04
#     --------------------------------------- 0.3/10.6 MB 3.2 MB/s eta 0:00:04
#    - -------------------------------------- 0.4/10.6 MB 3.3 MB/s eta 0:00:04
#    - -------------------------------------- 0.5/10.6 MB 2.6 MB/s eta 0:00:04
#    -- ------------------------------------- 0.6/10.6 MB 2.8 MB/s eta 0:00:04
#    -- ------------------------------------- 0.8/10.6 MB 2.8 MB/s eta 0:00:04
#    --- ------------------------------------ 0.9/10.6 MB 2.8 MB/s eta 0:00:04
# ...

# %% [markdown]
# ## Importamos las librerías necesarias

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.metrics import mean_absolute_error
from sklearn.linear_model import LinearRegression 


import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 4
#       2 import pandas as pd
#       3 import seaborn as sns
# ----> 4 from sklearn.metrics import mean_absolute_error
#       5 from sklearn.linear_model import LinearRegression
#       8 import numpy as np
#
# ModuleNotFoundError: No module named 'sklearn'

# %% [markdown]
# El conjunto de datos contiene 506 registros y 14 atributos, que incluyen información como la tasa de impuesto a la propiedad, la proporción de habitaciones por vivienda ocupada, la tasa de criminalidad per cápita, entre otros.
#
# CRIM: tasa de delincuencia per cápita por ciudad
#
# ZN: proporción de terrenos residenciales zonificados para lotes de más de 25.000 pies cuadrados
#
# INDUS: proporción de acres de negocios no minoristas por ciudad
#
# CHAS: variable ficticia del río Charles (= 1 si la parcela limita con el río; 0 en caso contrario)
#
# NOX: concentración de óxidos nítricos (partes por cada 10 millones)
#
# RM: número promedio de habitaciones por vivienda
#
# AGE: proporción de unidades ocupadas por sus propietarios construidas antes de 1940
#
# DIS: distancias ponderadas a cinco centros de empleo de Boston
#
# RAD: índice de accesibilidad a carreteras radiales
#
# TAX: tasa de impuesto sobre la propiedad de valor total por cada $10,000
#
# PTRATIO: relación alumno-maestro por ciudad
#
# B: 1000(Bk - 0.63)^2 donde Bk es la proporción de negros por ciudad
#
# LSTAT: % de estatus social bajo de la población
#
# MEDV: valor mediano de las viviendas ocupadas por sus propietarios en miles de dólares ($1000)

# %%
df = pd.read_csv(
    'https://archive.ics.uci.edu/ml/machine-learning-databases/housing/housing.data', 
    header=None, # especificamos que el dataset no tiene headers.
    sep='\s+')

df.columns = ["CRIM","ZN","INDUS" , "CHAS" ,"NOX","RM" ,"AGE","DIS", "RAD","TAX", "PTRATIO", "B" , "LSTAT" , "MEDV"]

df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273.0
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273.0
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273.0
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273.0
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273.0
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# ...

# %% [markdown]
# ### Preparamos los datos

# %%
# Guardamos los datos de interes en una variable x e y
x = pd.DataFrame(df['RM'])
y = pd.DataFrame(df['MEDV'])

# %% [markdown]
# ### Ajustamos el modelo

# %%
# Instanciamos y ajustamos el modelo de regresión lineal
model = LinearRegression() # Standar Linear Regression (slr)
model.fit(x, y)

print(model.coef_)
print(model.intercept_)
# Out:
# [[9.10210898]]
# [-34.67062078]

# %% [markdown]
# ### Predecimos

# %%
y_pred=model.predict(x)

# %%
# Graficamos los datos estandarizados
plt.scatter(x, y)
# Graficamos la linea de regresion ajustada
plt.plot(x, y_pred, color='red')

plt.xlabel("Promedio de habitaciones")
plt.ylabel("Mediana del precio de las casas")
# Out:
# Text(0, 0.5, 'Mediana del precio de las casas')

# %% [markdown]
# ### Medimos el desempeño

# %%
df_errores=pd.DataFrame()
df_errores['Real']=y
df_errores['Predicho']=y_pred
df_errores
# Out:
#      Real   Predicho
# 0    24.0  25.175746
# 1    21.6  23.774021
# 2    34.7  30.728032
# 3    33.4  29.025938
# 4    36.2  30.382152
# ..    ...        ...
# 501  22.4  25.339584
# 502  20.6  21.034286
# 503  23.9  28.825691
# 504  22.0  27.169108
# 505  11.9  20.215096
#
# [506 rows x 2 columns]

# %% [markdown]
# # EJERCICIO 1

# %% [markdown]
# ###### Calcula manualmente cual sería el valor predicho por el modelo para una vivienda con 20 habitaciones ('RM'=20)

# %%
-34 + 9.1 * 20
# Out:
# 148.0

# %% [markdown]
# # EJERCICIO 2

# %% [markdown]
# ###### Crea en df_errores una columna con el error cometido por el modelo en cada registro

# %%
df_errores["error"] = df_errores["Real"] - df_errores["Predicho"]
df_errores
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df_errores = df_errores["Real"] - df_errores["Predicho"]
#       2 df_errores
#
# NameError: name 'df_errores' is not defined

# %% [markdown]
# ###### Crea en df_errores una columna con el error en valor absoluto cometido por el modelo en cada registro

# %% [markdown]
# ###### Crea en df_errores una columna con el error al cuadrado cometido por el modelo en cada registro

# %% [markdown]
# ###### Crea en df_errores una columna con el error en valor absoluto porcentual (o relativo) en cada registro

# %% [markdown]
# ###### Calcula el error total cometido

# %% [markdown]
# ###### Calcula el error en valor absoluto total cometido

# %% [markdown]
# ###### Calcula el error en valor al cuadrado medio cometido

# %% [markdown]
# ###### Calcula el error en valor absoluto medio cometido

# %% [markdown]
# # EJERCICIO 3

# %% [markdown]
# ###### Elige una variable que pueda ayudar a explicar 'RM'

# %% [markdown]
# ###### Ajusta un modelo entre 'RM' y la variable que has elegido

# %% [markdown]
# ###### Simula que valores hubiera dado tu modelo a 'RM'

# %% [markdown]
# ###### Plotea los valores reales y los simulados

# %% [markdown]
# ###### Mide el error cometido

# %% [markdown]
# ###### Plotea los valores reales y predichos
